# %%
import psycopg2 as pg
import pandas as pd

connection = pg.connect(host='pgsql-196447.vipserv.org', port=5432, dbname='wbauer_adb', user='wbauer_adb', password='adb2020')

# %%
df = pd.read_sql('select * from city', con=connection)
df
# Out:
#      customer_id  store_id first_name  last_name  \
# 0            524         1      Jared        Ely
# 1              1         1       Mary      Smith
# 2              2         1   Patricia    Johnson
# 3              3         1      Linda   Williams
# 4              4         2    Barbara      Jones
# ..           ...       ...        ...        ...
# 594          595         1   Terrence  Gunderson
# 595          596         1    Enrique   Forsythe
# 596          597         1    Freddie     Duggan
# 597          598         1       Wade   Delvalle
# 598          599         2     Austin    Cintron
#
#                                      email  address_id  activebool  \
# 0             jared.ely@sakilacustomer.org         530        True
# 1            mary.smith@sakilacustomer.org           5        True
# 2      patricia.johnson@sakilacustomer.org           6        True
# 3        linda.williams@sakilacustomer.org           7        True
# ...

# %%
# 1.
df_movie_genre_dist = pd.read_sql('SELECT * FROM category', con=connection)
df_movie_genre_dist
# Out:
#     category_id         name         last_update
# 0             1       Action 2006-02-15 09:46:27
# 1             2    Animation 2006-02-15 09:46:27
# 2             3     Children 2006-02-15 09:46:27
# 3             4     Classics 2006-02-15 09:46:27
# 4             5       Comedy 2006-02-15 09:46:27
# 5             6  Documentary 2006-02-15 09:46:27
# 6             7        Drama 2006-02-15 09:46:27
# 7             8       Family 2006-02-15 09:46:27
# 8             9      Foreign 2006-02-15 09:46:27
# 9            10        Games 2006-02-15 09:46:27
# 10           11       Horror 2006-02-15 09:46:27
# 11           12        Music 2006-02-15 09:46:27
# 12           13          New 2006-02-15 09:46:27
# 13           14       Sci-Fi 2006-02-15 09:46:27
# 14           15       Sports 2006-02-15 09:46:27
# 15           16       Travel 2006-02-15 09:46:27

# %%
# 2.
df_movie_genre_alphabet = pd.read_sql('SELECT * FROM category ORDER BY name ASC;', con=connection)
df_movie_genre_alphabet
# Out:
#     category_id         name         last_update
# 0             1       Action 2006-02-15 09:46:27
# 1             2    Animation 2006-02-15 09:46:27
# 2             3     Children 2006-02-15 09:46:27
# 3             4     Classics 2006-02-15 09:46:27
# 4             5       Comedy 2006-02-15 09:46:27
# 5             6  Documentary 2006-02-15 09:46:27
# 6             7        Drama 2006-02-15 09:46:27
# 7             8       Family 2006-02-15 09:46:27
# 8             9      Foreign 2006-02-15 09:46:27
# 9            10        Games 2006-02-15 09:46:27
# 10           11       Horror 2006-02-15 09:46:27
# 11           12        Music 2006-02-15 09:46:27
# 12           13          New 2006-02-15 09:46:27
# 13           14       Sci-Fi 2006-02-15 09:46:27
# 14           15       Sports 2006-02-15 09:46:27
# 15           16       Travel 2006-02-15 09:46:27

# %%
# 3.

movies_release = pd.read_sql('SELECT release_year FROM film', con=connection)
movies_release
# youngest_movie = pd.read_sql('SELECT MIN(release_year) FROM film', con=connection)
# print(youngest_movie)
# eldest_movie = pd.read_sql('SELECT MAX(release_year) FROM film', con=connection)
# print(eldest_movie)
# Out:
#      release_year
# 0            2006
# 1            2006
# 2            2006
# 3            2006
# 4            2006
# ..            ...
# 995          2006
# 996          2006
# 997          2006
# 998          2006
# 999          2006
#
# [1000 rows x 1 columns]

# %%
# 4. 

# rents_between2005 = pd.read_sql('SELECT COUNT rental_date FROM rental WHERE rental_date > TIMESTAMP(2005-07-01)', con=connection)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# ~/.conda/envs/magdalenaleonkiewicz/lib/python3.9/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# SyntaxError: syntax error at or near "-"
# LINE 1: ...l_date FROM rental WHERE rental_date > TIMESTAMP(2005-07-01)
#                                                                 ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_25948/3562593031.py in <module>
#       1 # 4.
#       2
# ----> 3 rents_between2005 = pd.read_sql('SELECT COUNT rental_date FROM rental WHERE rental_date > TIMESTAMP(2005-07-01)', con=connection)
#
# ...

# %%
# 5.

# %%
# 6.
highest_payment = pd.read_sql('SELECT MAX(amount) FROM payment', con=connection)
highest_payment
# Out:
#      max
# 0  11.99

# %%
#7. 
clients = pd.read_sql('SELECT country FROM country', con=connection)
clients


pol_neg_bang = pd.read_sql('SELECT country FROM country WHERE country IN (Algeria);', con=connection)
pol_neg_bang
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~/.conda/envs/magdalenaleonkiewicz/lib/python3.9/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# UndefinedColumn: column "algeria" does not exist
# LINE 1: SELECT country FROM country WHERE country IN (Algeria);
#                                                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_25948/3066947035.py in <module>
#       4
#       5
# ----> 6 pol_neg_bang = pd.read_sql('SELECT country FROM country WHERE country IN (Algeria);', con=connection)
#       7 pol_neg_bang
#
# ...
